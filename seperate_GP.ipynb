# %%
import re 
import pandas
gp_table = pandas.read_csv("GP_step.csv")
for i in [6.0, 7.0, 8.0, 10.0, 12.0, 14.0, 15.0, 16.0, 17.0, 26.0, 27.0, 28.0, 29.0, 30.0]:
    f = open("gp_"+str(i), 'w')
    table_i = gp_table[gp_table.Pathway == i]
    table_i.to_csv(f)

# %%
gp_6 = pandas.read_csv("gp_6.0")
gp_6
# Out:
#     Unnamed: 0  Pathway           Pathway_name  Step  Product   Metacyc  \
# 0            0      6.0  Bifidobacterium shunt   1.0  Acetate  P124-PWY
# 1            1      6.0  Bifidobacterium shunt   2.0  Acetate  P124-PWY
# 2            2      6.0  Bifidobacterium shunt   3.0  Acetate  P124-PWY
# 3            3      6.0  Bifidobacterium shunt   4.0  Acetate  P124-PWY
# 4            5      6.0  Bifidobacterium shunt   1.0  Acetate  P124-PWY
# 5            6      6.0  Bifidobacterium shunt   2.0  Acetate  P124-PWY
# 6            7      6.0  Bifidobacterium shunt   3.0  Acetate  P124-PWY
# 7            8      6.0  Bifidobacterium shunt   4.0  Acetate  P124-PWY
# 8            9      6.0  Bifidobacterium shunt   5.0  Acetate  P124-PWY
# 9           10      6.0  Bifidobacterium shunt   6.0  Acetate  P124-PWY
# 10          11      6.0  Bifidobacterium shunt   7.0  Acetate  P124-PWY
# 11          12      6.0  Bifidobacterium shunt   8.0  Acetate  P124-PWY
# ...

# %%
#f6 = open("gp_6_1_DESC", "w")
f_7_2 = open("gp_7_2", "w")
gp_7 = pandas.read_csv("gp_7.0")
#gp_7
gp_7_2 = gp_7.iloc[9:, ]
#gp_7_2
gp_7_2.to_csv(f_7_2)

# %%
f_8_1 = open("gp_8_1", "w")
gp_8 = pandas.read_csv("gp_8.0")
#gp_8
gp_8_1 = gp_8.iloc[:8, ]
#gp_8_1
gp_8_1.to_csv(f_8_1)

# %%
import pandas
gp_17 = pandas.read_csv("gp_17.0")

# %%
gp_17
# Out:
#    Unnamed: 0  Pathway                                       Pathway_name  \
# 0          84     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
# 1          85     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
# 2          86     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
# 3          87     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
# 4          88     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
# 5          89     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
# 6          90     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
# 7          92     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
# 8          93     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
# 9          94     17.0  L-glutamate degradation IX (via 4-aminobutanoate)
#
#    Step    Product    Metacyc  Author               EC  \
# 0   1.0  Butanoate  PWY0-1305  Hong E         4.1.1.15
# ...

# %%
gp_17_1 = gp_17.iloc[:7, ]
#gp_17_1
f_17_1 = open("gp_17_1.csv", "w")
gp_17_1.to_csv(f_17_1)

# %%
gp_17_2 = gp_17.iloc[7:, ]
#gp_17_2
f_17_2 = open("gp_17_2.csv", "w")
gp_17_2.to_csv(f_17_2)

# %%
import pandas
gp_28 = pandas.read_csv("gp_28.0")
gp_28
# Out:
#    Unnamed: 0  Pathway                                      Pathway_name  \
# 0         107     28.0  L-alanine fermentation to propanoate and acetate
# 1         108     28.0  L-alanine fermentation to propanoate and acetate
# 2         109     28.0  L-alanine fermentation to propanoate and acetate
# 3         110     28.0  L-alanine fermentation to propanoate and acetate
# 4         111     28.0  L-alanine fermentation to propanoate and acetate
# 5         112     28.0  L-alanine fermentation to propanoate and acetate
# 6         114     28.0  L-alanine fermentation to propanoate and acetate
# 7         115     28.0  L-alanine fermentation to propanoate and acetate
# 8         116     28.0  L-alanine fermentation to propanoate and acetate
# 9         117     28.0  L-alanine fermentation to propanoate and acetate
#
#    Step     Product       Metacyc               Author                EC  \
# 0   1.0  Propanoate  PROPFERM-PWY  Fulcher CA, Caspi R           2.6.1.2
# ...

# %%
gp_28_2 = gp_28.iloc[6:, ]
#gp_28_1
f_28_2 = open("gp_28_2.csv", "w")
gp_28_2.to_csv(f_28_2)

# %%
import pandas
gp_29 = pandas.read_csv("gp_29.0")
gp_29
# Out:
#     Unnamed: 0  Pathway            Pathway_name  Step       Product   Metacyc  \
# 0          119     29.0  bile acids degradation   1.0  lithocholate  PWY-7754
# 1          120     29.0  bile acids degradation   2.0  lithocholate  PWY-7754
# 2          121     29.0  bile acids degradation   3.0  lithocholate  PWY-7754
# 3          122     29.0  bile acids degradation   4.0  lithocholate  PWY-7754
# 4          123     29.0  bile acids degradation   5.0  lithocholate  PWY-7754
# 5          124     29.0  bile acids degradation   6.0  lithocholate  PWY-7754
# 6          125     29.0  bile acids degradation   7.0  lithocholate  PWY-7754
# 7          126     29.0  bile acids degradation   8.0  lithocholate  PWY-7754
# 8          127     29.0  bile acids degradation   9.0  lithocholate  PWY-7754
# 9          129     29.0  bile acids degradation   1.0  deoxycholate  PWY-7754
# 10         130     29.0  bile acids degradation   2.0  deoxycholate  PWY-7754
# ...

# %%
gp_29_2 = gp_29.iloc[9:, ]
#gp_28_1
f_29_2 = open("gp_29_2.csv", "w")
gp_29_2.to_csv(f_29_2)

# %%
import pandas
gp_table = pandas.read_csv("GP_step.csv")
gp_table
# Out:
#      Pathway                                      Pathway_name  Step  \
# 0        6.0                             Bifidobacterium shunt   1.0
# 1        6.0                             Bifidobacterium shunt   2.0
# 2        6.0                             Bifidobacterium shunt   3.0
# 3        6.0                             Bifidobacterium shunt   4.0
# 4        NaN                                               NaN   NaN
# 5        6.0                             Bifidobacterium shunt   1.0
# 6        6.0                             Bifidobacterium shunt   2.0
# 7        6.0                             Bifidobacterium shunt   3.0
# 8        6.0                             Bifidobacterium shunt   4.0
# 9        6.0                             Bifidobacterium shunt   5.0
# 10       6.0                             Bifidobacterium shunt   6.0
# 11       6.0                             Bifidobacterium shunt   7.0
# 12       6.0                             Bifidobacterium shunt   8.0
# ...

# %%
#f = open("gp_30.0", "w")
table_30 = gp_table[gp_table.Pathway == 30]
table_30
# Out:
#      Pathway                        Pathway_name  Step       Product  \
# 138     30.0  glycocholate metabolism (bacteria)   1.0  7-epicholate
# 139     30.0  glycocholate metabolism (bacteria)   2.0  7-epicholate
# 140     30.0  glycocholate metabolism (bacteria)   3.0  7-epicholate
# 142     30.0  glycocholate metabolism (bacteria)   1.0    trihydroxy
# 143     30.0  glycocholate metabolism (bacteria)   2.0    trihydroxy
# 144     30.0  glycocholate metabolism (bacteria)   3.0    trihydroxy
# 146     30.0  glycocholate metabolism (bacteria)   1.0    isocholate
# 147     30.0  glycocholate metabolism (bacteria)   2.0    isocholate
# 148     30.0  glycocholate metabolism (bacteria)   3.0    isocholate
#
#       Metacyc      Author         EC  \
# 138  PWY-6518  Fulcher CA   3.5.1.24
# 139  PWY-6518  Fulcher CA  1.1.1.159
# 140  PWY-6518  Fulcher CA  1.1.1.201
# 142  PWY-6518  Fulcher CA   3.5.1.24
# 143  PWY-6518  Fulcher CA  1.1.1.176
# 144  PWY-6518  Fulcher CA  1.1.1.238
# ...

# %%
gp_30_3 = table_30.iloc[6:, ]
#gp_30_3
f_30_3 = open("gp_30_3.csv", "w")
gp_30_3.to_csv(f_30_3)
